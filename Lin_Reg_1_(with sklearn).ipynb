# %% [markdown]
# <a href="https://colab.research.google.com/github/SidharrthSingh25/Sem_4_ML-AI/blob/main/Lin_Reg_1_(with%20sklearn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. DATA PREPROCESSING

# %% [markdown]
# 1.1 IMPORTING LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1.2 IMPORTING DATASETS

# %%
dataset = pd.read_csv ('headbrain.csv')
X = dataset.iloc [ : , 2].values
Y = dataset.iloc [ : , -1].values

# %%
print (dataset)
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
X = X.reshape (len (X),1)
print (X)
# Out:
# [[4512]
#  [3738]
#  [4261]
#  [3777]
#  [4177]
#  [3585]
#  [3785]
#  [3559]
#  [3613]
#  [3982]
#  [3443]
#  [3993]
#  [3640]
#  [4208]
#  [3832]
#  [3876]
#  [3497]
#  [3466]
#  [3095]
#  [4424]
#  [3878]
#  [4046]
#  [3804]
#  [3710]
#  [4747]
#  [4423]
#  [4036]
#  [4022]
#  [3454]
#  [4175]
#  [3787]
#  [3796]
#  [4103]
#  [4161]
#  [4158]
#  [3814]
#  [3527]
#  [3748]
#  [3334]
#  [3492]
#  [3962]
#  [3505]
#  [4315]
#  [3804]
#  [3863]
#  [4034]
#  [4308]
#  [3165]
#  [3641]
#  [3644]
#  [3891]
#  [3793]
#  [4270]
#  [4063]
#  [4012]
#  [3458]
#  [3890]
#  [4166]
#  [3935]
#  [3669]
#  [3866]
#  [3393]
#  [4442]
#  [4253]
#  [3727]
#  [3329]
#  [3415]
#  [3372]
#  [4430]
#  [4381]
#  [4008]
#  [3858]
#  [4121]
#  [4057]
#  [3824]
#  [3394]
#  [3558]
#  [3362]
#  [3930]
#  [3835]
#  [3830]
#  [3856]
#  [3249]
#  [3577]
#  [3933]
#  [3850]
#  [3309]
#  [3406]
#  [3506]
#  [3907]
#  [4160]
#  [3318]
#  [3662]
#  [3899]
#  [3700]
#  [3779]
#  [3473]
#  [3490]
#  [3654]
#  [3478]
# ...

# %%
Y = Y.reshape (len (Y),1)
print (Y)
# Out:
# [[1530]
#  [1297]
#  [1335]
#  [1282]
#  [1590]
#  [1300]
#  [1400]
#  [1255]
#  [1355]
#  [1375]
#  [1340]
#  [1380]
#  [1355]
#  [1522]
#  [1208]
#  [1405]
#  [1358]
#  [1292]
#  [1340]
#  [1400]
#  [1357]
#  [1287]
#  [1275]
#  [1270]
#  [1635]
#  [1505]
#  [1490]
#  [1485]
#  [1310]
#  [1420]
#  [1318]
#  [1432]
#  [1364]
#  [1405]
#  [1432]
#  [1207]
#  [1375]
#  [1350]
#  [1236]
#  [1250]
#  [1350]
#  [1320]
#  [1525]
#  [1570]
#  [1340]
#  [1422]
#  [1506]
#  [1215]
#  [1311]
#  [1300]
#  [1224]
#  [1350]
#  [1335]
#  [1390]
#  [1400]
#  [1225]
#  [1310]
#  [1560]
#  [1330]
#  [1222]
#  [1415]
#  [1175]
#  [1330]
#  [1485]
#  [1470]
#  [1135]
#  [1310]
#  [1154]
#  [1510]
#  [1415]
#  [1468]
#  [1390]
#  [1380]
#  [1432]
#  [1240]
#  [1195]
#  [1225]
#  [1188]
#  [1252]
#  [1315]
#  [1245]
#  [1430]
#  [1279]
#  [1245]
#  [1309]
#  [1412]
#  [1120]
#  [1220]
#  [1280]
#  [1440]
#  [1370]
#  [1192]
#  [1230]
#  [1346]
#  [1290]
#  [1165]
#  [1240]
#  [1132]
#  [1242]
#  [1270]
# ...

# %% [markdown]
# 1.3 SPLITTING INTO TRAINING AND TEST SET

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size = 0.2, random_state = 0)

# %%
print (X_train)
# Out:
# [[3104]
#  [3069]
#  [3402]
#  [3662]
#  [3577]
#  [4161]
#  [3394]
#  [3279]
#  [3071]
#  [3248]
#  [3727]
#  [2939]
#  [3170]
#  [3391]
#  [3297]
#  [3399]
#  [3497]
#  [3899]
#  [3473]
#  [4177]
#  [3618]
#  [3393]
#  [3269]
#  [4270]
#  [3415]
#  [4036]
#  [3558]
#  [3156]
#  [2937]
#  [3962]
#  [4208]
#  [3777]
#  [3302]
#  [4747]
#  [3787]
#  [3735]
#  [3866]
#  [3890]
#  [3582]
#  [3695]
#  [4424]
#  [3609]
#  [4051]
#  [4012]
#  [3703]
#  [3830]
#  [3793]
#  [4006]
#  [3548]
#  [3853]
#  [3309]
#  [3614]
#  [3360]
#  [3704]
#  [3566]
#  [3505]
#  [3832]
#  [4022]
#  [3891]
#  [3586]
#  [3878]
#  [3707]
#  [4308]
#  [3779]
#  [3214]
#  [3791]
#  [2989]
#  [4442]
#  [3666]
#  [4261]
#  [3669]
#  [3903]
#  [3381]
#  [3804]
#  [3354]
#  [3443]
#  [3436]
#  [4057]
#  [4204]
#  [3685]
#  [3571]
#  [3503]
#  [3654]
#  [3899]
#  [3156]
#  [3284]
#  [3594]
#  [4512]
#  [3700]
#  [3779]
#  [4381]
#  [3644]
#  [3641]
#  [3850]
#  [3233]
#  [3530]
#  [3710]
#  [3438]
#  [3930]
#  [3495]
# ...

# %%
print (Y_train)
# Out:
# [[1080]
#  [1022]
#  [1220]
#  [1230]
#  [1245]
#  [1405]
#  [1195]
#  [1265]
#  [1078]
#  [1250]
#  [1470]
#  [1060]
#  [1178]
#  [1125]
#  [1220]
#  [1226]
#  [1358]
#  [1380]
#  [1240]
#  [1590]
#  [1290]
#  [1175]
#  [1241]
#  [1335]
#  [1310]
#  [1490]
#  [1225]
#  [1225]
#  [1070]
#  [1350]
#  [1522]
#  [1282]
#  [1165]
#  [1635]
#  [1318]
#  [1350]
#  [1415]
#  [1310]
#  [1300]
#  [1310]
#  [1400]
#  [1210]
#  [1306]
#  [1400]
#  [1350]
#  [1245]
#  [1350]
#  [1302]
#  [1460]
#  [1373]
#  [1120]
#  [1180]
#  [1095]
#  [1220]
#  [1306]
#  [1320]
#  [1208]
#  [1485]
#  [1224]
#  [1250]
#  [1357]
#  [1235]
#  [1506]
#  [1520]
#  [1110]
#  [1260]
#  [1130]
#  [1330]
#  [1270]
#  [1335]
#  [1222]
#  [1334]
#  [1185]
#  [1570]
#  [1204]
#  [1340]
#  [1235]
#  [1432]
#  [1380]
#  [1350]
#  [1295]
#  [1240]
#  [1242]
#  [1346]
#  [1170]
#  [1246]
#  [1290]
#  [1530]
#  [1290]
#  [1165]
#  [1415]
#  [1300]
#  [1311]
#  [1412]
#  [1104]
#  [1252]
#  [1270]
#  [1290]
#  [1252]
#  [1218]
# ...

# %%
print (X_test)
# Out:
# [[3724]
#  [3680]
#  [4032]
#  [3524]
#  [3782]
#  [3647]
#  [4488]
#  [3533]
#  [4034]
#  [3851]
#  [4114]
#  [3067]
#  [3318]
#  [3834]
#  [3391]
#  [3439]
#  [3632]
#  [3916]
#  [3479]
#  [3613]
#  [3458]
#  [4160]
#  [3907]
#  [3585]
#  [3804]
#  [3748]
#  [3171]
#  [3640]
#  [4430]
#  [2857]
#  [3268]
#  [3589]
#  [3479]
#  [4005]
#  [3863]
#  [3413]
#  [3803]
#  [3995]
#  [3824]
#  [3490]
#  [3858]
#  [3095]
#  [3090]
#  [3876]
#  [4253]
#  [3559]
#  [3401]
#  [3145]]

# %%
print (Y_test)
# Out:
# [[1280]
#  [1321]
#  [1425]
#  [1250]
#  [1350]
#  [1408]
#  [1440]
#  [1210]
#  [1422]
#  [1405]
#  [1362]
#  [1150]
#  [1175]
#  [1430]
#  [1120]
#  [1192]
#  [1163]
#  [1360]
#  [1160]
#  [1355]
#  [1225]
#  [1370]
#  [1440]
#  [1300]
#  [1275]
#  [1350]
#  [1127]
#  [1355]
#  [1620]
#  [1027]
#  [1142]
#  [1250]
#  [1103]
#  [1280]
#  [1340]
#  [1322]
#  [1374]
#  [1296]
#  [1240]
#  [1132]
#  [1390]
#  [1340]
#  [1168]
#  [1405]
#  [1485]
#  [1255]
#  [1140]
#  [1202]]

# %% [markdown]
# ## 2. TRAINING LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit (X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## 3. PREDICTING TEST SET RESULTS

# %%
Y_pred = regressor.predict (X_test)
print (Y_pred)
# Out:
# [[1306.48231242]
#  [1294.99527544]
#  [1386.89157129]
#  [1254.26850796]
#  [1321.62431571]
#  [1286.3799977 ]
#  [1505.93904546]
#  [1256.61812916]
#  [1387.41370934]
#  [1339.63807825]
#  [1408.29923112]
#  [1134.95996476]
#  [1200.48828936]
#  [1335.19990487]
#  [1219.54632799]
#  [1232.07764106]
#  [1282.46396237]
#  [1356.6075647 ]
#  [1242.52040195]
#  [1277.50365094]
#  [1237.03795249]
#  [1420.30840615]
#  [1354.2579435 ]
#  [1270.19371832]
#  [1327.3678342 ]
#  [1312.74796896]
#  [1162.11114308]
#  [1284.55251455]
#  [1490.79704217]
#  [1080.13547008]
#  [1187.43483825]
#  [1271.23799441]
#  [1242.52040195]
#  [1379.84270769]
#  [1342.77090652]
#  [1225.28984648]
#  [1327.10676518]
#  [1377.23201747]
#  [1332.58921465]
#  [1245.3921612 ]
#  [1341.46556141]
#  [1142.26989739]
#  [1140.96455228]
#  [1346.16480381]
#  [1444.58782522]
#  [1263.40592374]
#  [1222.15701821]
#  [1155.3233485 ]]

# %%
print (np.concatenate ((Y_pred.reshape (len (Y_pred),1), Y_test.reshape (len (Y_test),1)),1))
# Out:
# [[1306.48231242 1280.        ]
#  [1294.99527544 1321.        ]
#  [1386.89157129 1425.        ]
#  [1254.26850796 1250.        ]
#  [1321.62431571 1350.        ]
#  [1286.3799977  1408.        ]
#  [1505.93904546 1440.        ]
#  [1256.61812916 1210.        ]
#  [1387.41370934 1422.        ]
#  [1339.63807825 1405.        ]
#  [1408.29923112 1362.        ]
#  [1134.95996476 1150.        ]
#  [1200.48828936 1175.        ]
#  [1335.19990487 1430.        ]
#  [1219.54632799 1120.        ]
#  [1232.07764106 1192.        ]
#  [1282.46396237 1163.        ]
#  [1356.6075647  1360.        ]
#  [1242.52040195 1160.        ]
#  [1277.50365094 1355.        ]
#  [1237.03795249 1225.        ]
#  [1420.30840615 1370.        ]
#  [1354.2579435  1440.        ]
#  [1270.19371832 1300.        ]
#  [1327.3678342  1275.        ]
#  [1312.74796896 1350.        ]
#  [1162.11114308 1127.        ]
#  [1284.55251455 1355.        ]
#  [1490.79704217 1620.        ]
#  [1080.13547008 1027.        ]
# ...

# %% [markdown]
# ## 4. VISUALISING RESULTS

# %% [markdown]
# 4.1 TRAINING SET

# %%
plt.scatter (X_train, Y_train, color = 'red')
plt.plot (X_train, regressor.predict (X_train), color = 'blue')
plt.title ('TRAINING SET RESULTS')
plt.xlabel ('Head Size (cm^3)')
plt.ylabel ('Brain Weight (grams)')
plt.show ()

# %% [markdown]
# 4.2 TEST SET

# %%
plt.scatter (X_test, Y_test, color = 'red')
plt.plot (X_test, Y_pred, color = 'blue')
plt.title ('TEST SET RESULTS')
plt.xlabel ('Head Size (cm^3)')
plt.ylabel ('Brain Weight (grams)')
plt.show ()

# %% [markdown]
# ## 5. ACCURACY OF MODEL

# %%
from sklearn.metrics import r2_score
acc = r2_score (Y_test, Y_pred)
print ('Accuracy of Regression Model is - ', acc)
# Out:
# Accuracy of Regression Model is -  0.6376364238008985
