# %% [markdown]
# <a href="https://colab.research.google.com/github/SidharrthSingh25/Sem_4_ML-AI/blob/main/Lin_Reg_2_(with%20sklearn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. DATA PREPROCESSING

# %% [markdown]
# 1.1 IMPORTING LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1.2 IMPORTING DATASETS

# %%
dataset = pd.read_csv ('Linear_reg_iris.csv - Linear_reg_iris.csv.csv')
X = dataset.iloc [ : , 0].values
Y = dataset.iloc [ : , -1].values

# %%
print (dataset)
# Out:
#         X      Y
# 0    0.08  1.472
# 1    0.52  1.802
# 2    0.60  1.548
# 3    0.22  1.390
# 4    0.05  2.141
# ..    ...    ...
# 995  0.41  2.245
# 996  0.71  3.471
# 997  0.06  0.796
# 998  0.40  2.406
# 999  0.48  1.870
#
# [1000 rows x 2 columns]

# %%
X = X.reshape (len (X),1)
print (X)
# Out:
# [[0.08]
#  [0.52]
#  [0.6 ]
#  [0.22]
#  [0.05]
#  [0.59]
#  [0.94]
#  [0.39]
#  [0.52]
#  [0.31]
#  [0.69]
#  [0.46]
#  [0.76]
#  [0.39]
#  [0.37]
#  [0.78]
#  [0.39]
#  [0.33]
#  [0.72]
#  [0.88]
#  [0.26]
#  [0.2 ]
#  [0.75]
#  [0.46]
#  [0.95]
#  [0.86]
#  [0.05]
#  [0.72]
#  [0.06]
#  [0.99]
#  [0.97]
#  [0.93]
#  [0.12]
#  [0.66]
#  [0.4 ]
#  [0.37]
#  [0.31]
#  [0.88]
#  [0.26]
#  [0.34]
#  [0.69]
#  [0.72]
#  [0.41]
#  [0.78]
#  [0.06]
#  [0.07]
#  [0.44]
#  [0.92]
#  [0.85]
#  [0.75]
#  [0.41]
#  [0.3 ]
#  [0.61]
#  [0.51]
#  [0.73]
#  [0.81]
#  [0.85]
#  [0.1 ]
#  [0.59]
#  [0.75]
#  [0.51]
#  [0.11]
#  [0.85]
#  [0.55]
#  [0.4 ]
#  [0.96]
#  [0.22]
#  [0.37]
#  [0.42]
#  [0.85]
#  [0.53]
#  [0.81]
#  [0.31]
#  [0.14]
#  [0.99]
#  [0.38]
#  [0.72]
#  [0.08]
#  [0.32]
#  [0.28]
#  [0.37]
#  [0.41]
#  [0.42]
#  [0.15]
#  [0.79]
#  [0.08]
#  [0.68]
#  [0.07]
#  [0.78]
#  [0.49]
#  [0.47]
#  [0.3 ]
#  [0.06]
#  [0.07]
#  [0.99]
#  [0.91]
#  [0.66]
#  [1.  ]
#  [0.36]
#  [0.2 ]
# ...

# %%
Y = Y.reshape (len (Y),1)
print (Y)
# Out:
# [[1.472]
#  [1.802]
#  [1.548]
#  [1.39 ]
#  [2.141]
#  [3.541]
#  [3.898]
#  [2.699]
#  [2.152]
#  [1.325]
#  [3.647]
#  [2.476]
#  [3.164]
#  [3.257]
#  [0.869]
#  [1.994]
#  [2.573]
#  [3.313]
#  [3.478]
#  [3.426]
#  [3.216]
#  [0.48 ]
#  [3.495]
#  [1.518]
#  [4.245]
#  [3.172]
#  [2.895]
#  [4.004]
#  [2.074]
#  [2.791]
#  [3.233]
#  [3.099]
#  [0.72 ]
#  [2.54 ]
#  [2.146]
#  [3.357]
#  [0.649]
#  [1.706]
#  [1.278]
#  [2.712]
#  [2.059]
#  [3.956]
#  [3.215]
#  [3.048]
#  [2.43 ]
#  [2.377]
#  [1.62 ]
#  [4.268]
#  [3.583]
#  [3.595]
#  [2.801]
#  [2.712]
#  [2.507]
#  [2.965]
#  [3.041]
#  [2.799]
#  [3.169]
#  [1.528]
#  [3.563]
#  [2.389]
#  [1.537]
#  [2.877]
#  [2.361]
#  [2.433]
#  [3.256]
#  [3.746]
#  [1.848]
#  [1.135]
#  [3.762]
#  [3.235]
#  [2.887]
#  [3.719]
#  [2.321]
#  [1.212]
#  [3.917]
#  [2.352]
#  [2.42 ]
#  [1.766]
#  [2.2  ]
#  [2.786]
#  [1.859]
#  [1.139]
#  [3.296]
#  [1.791]
#  [3.073]
#  [1.95 ]
#  [1.632]
#  [1.561]
#  [3.318]
#  [1.781]
# ...

# %% [markdown]
# 1.3 SPLITTING INTO TRAINING AND TEST SET

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size = 0.2, random_state = 0)

# %%
print (X_train)
# Out:
# [[0.64]
#  [0.91]
#  [0.01]
#  [0.94]
#  [0.67]
#  [0.58]
#  [0.9 ]
#  [0.47]
#  [0.59]
#  [0.7 ]
#  [0.83]
#  [0.42]
#  [0.88]
#  [0.4 ]
#  [0.77]
#  [0.59]
#  [0.3 ]
#  [0.25]
#  [0.69]
#  [0.75]
#  [0.38]
#  [0.19]
#  [0.93]
#  [0.74]
#  [0.28]
#  [0.58]
#  [0.81]
#  [0.7 ]
#  [0.72]
#  [0.92]
#  [0.53]
#  [0.81]
#  [0.  ]
#  [0.23]
#  [0.85]
#  [0.28]
#  [0.88]
#  [0.33]
#  [0.11]
#  [0.39]
#  [0.16]
#  [0.03]
#  [0.8 ]
#  [0.32]
#  [0.99]
#  [0.12]
#  [0.26]
#  [0.6 ]
#  [0.52]
#  [0.75]
#  [0.88]
#  [0.57]
#  [0.08]
#  [0.93]
#  [0.38]
#  [0.05]
#  [0.06]
#  [0.08]
#  [0.6 ]
#  [0.26]
#  [0.43]
#  [0.96]
#  [0.17]
#  [0.84]
#  [0.88]
#  [0.61]
#  [0.6 ]
#  [0.62]
#  [0.12]
#  [0.64]
#  [0.77]
#  [0.93]
#  [0.41]
#  [0.72]
#  [0.91]
#  [0.62]
#  [0.73]
#  [0.1 ]
#  [0.59]
#  [0.05]
#  [0.11]
#  [0.59]
#  [0.2 ]
#  [0.32]
#  [0.16]
#  [0.34]
#  [0.81]
#  [0.47]
#  [0.85]
#  [0.47]
#  [0.51]
#  [0.25]
#  [0.62]
#  [0.55]
#  [0.33]
#  [0.01]
#  [0.4 ]
#  [0.98]
#  [0.92]
#  [0.69]
# ...

# %%
print (Y_train)
# Out:
# [[4.374]
#  [4.255]
#  [2.459]
#  [3.818]
#  [3.155]
#  [1.182]
#  [2.844]
#  [2.599]
#  [3.331]
#  [1.844]
#  [2.949]
#  [1.54 ]
#  [1.706]
#  [3.228]
#  [4.087]
#  [2.041]
#  [1.688]
#  [1.571]
#  [2.059]
#  [2.465]
#  [1.642]
#  [3.431]
#  [3.569]
#  [3.382]
#  [1.274]
#  [1.912]
#  [4.581]
#  [2.156]
#  [3.478]
#  [3.492]
#  [2.901]
#  [4.323]
#  [0.956]
#  [0.571]
#  [2.361]
#  [2.786]
#  [2.732]
#  [2.125]
#  [2.177]
#  [2.131]
#  [1.354]
#  [2.599]
#  [3.084]
#  [2.132]
#  [4.033]
#  [1.726]
#  [1.744]
#  [1.548]
#  [1.646]
#  [2.835]
#  [1.902]
#  [3.811]
#  [1.95 ]
#  [4.157]
#  [2.352]
#  [1.763]
#  [0.436]
#  [1.322]
#  [3.304]
#  [1.278]
#  [3.015]
#  [3.084]
#  [3.261]
#  [3.126]
#  [2.884]
#  [4.261]
#  [2.484]
#  [2.958]
#  [0.856]
#  [1.8  ]
#  [2.277]
#  [2.877]
#  [2.801]
#  [3.326]
#  [1.973]
#  [2.304]
#  [2.143]
#  [2.74 ]
#  [3.503]
#  [1.881]
#  [1.281]
#  [1.503]
#  [1.854]
#  [1.282]
#  [3.118]
#  [2.712]
#  [4.185]
#  [1.235]
#  [2.129]
#  [1.697]
# ...

# %%
print (X_test)
# Out:
# [[0.24]
#  [0.82]
#  [0.83]
#  [0.84]
#  [0.44]
#  [0.75]
#  [0.72]
#  [0.82]
#  [0.13]
#  [0.45]
#  [0.58]
#  [0.7 ]
#  [0.94]
#  [0.89]
#  [0.3 ]
#  [0.81]
#  [0.32]
#  [0.53]
#  [0.37]
#  [0.08]
#  [0.93]
#  [0.87]
#  [0.1 ]
#  [0.49]
#  [0.69]
#  [0.52]
#  [0.07]
#  [0.9 ]
#  [0.46]
#  [0.52]
#  [0.27]
#  [0.1 ]
#  [0.64]
#  [0.27]
#  [0.68]
#  [0.06]
#  [0.21]
#  [0.06]
#  [0.62]
#  [0.01]
#  [0.64]
#  [0.71]
#  [0.25]
#  [0.53]
#  [0.41]
#  [0.98]
#  [0.35]
#  [0.62]
#  [0.27]
#  [0.65]
#  [0.41]
#  [0.34]
#  [0.61]
#  [0.25]
#  [0.39]
#  [0.07]
#  [0.4 ]
#  [0.58]
#  [0.94]
#  [0.34]
#  [0.93]
#  [0.96]
#  [0.72]
#  [0.16]
#  [0.78]
#  [0.24]
#  [0.03]
#  [0.41]
#  [0.32]
#  [0.68]
#  [0.  ]
#  [0.  ]
#  [0.11]
#  [0.9 ]
#  [0.56]
#  [0.12]
#  [0.85]
#  [0.9 ]
#  [0.56]
#  [0.2 ]
#  [0.56]
#  [0.27]
#  [0.13]
#  [0.51]
#  [0.04]
#  [0.72]
#  [0.03]
#  [0.66]
#  [0.95]
#  [0.81]
#  [0.27]
#  [0.49]
#  [0.07]
#  [0.22]
#  [0.17]
#  [0.24]
#  [0.48]
#  [0.47]
#  [0.15]
#  [0.07]
# ...

# %%
print (Y_test)
# Out:
# [[1.436]
#  [3.28 ]
#  [3.017]
#  [3.172]
#  [3.3  ]
#  [3.233]
#  [4.004]
#  [3.348]
#  [1.819]
#  [2.887]
#  [2.246]
#  [3.546]
#  [3.658]
#  [3.371]
#  [1.77 ]
#  [2.799]
#  [1.378]
#  [4.199]
#  [0.869]
#  [1.766]
#  [3.099]
#  [4.609]
#  [2.672]
#  [2.327]
#  [1.831]
#  [1.968]
#  [2.377]
#  [3.49 ]
#  [3.398]
#  [1.802]
#  [1.223]
#  [1.216]
#  [2.648]
#  [2.415]
#  [3.058]
#  [2.252]
#  [2.621]
#  [1.498]
#  [2.374]
#  [1.501]
#  [2.964]
#  [3.471]
#  [2.771]
#  [1.593]
#  [2.781]
#  [4.17 ]
#  [1.301]
#  [3.414]
#  [2.523]
#  [2.195]
#  [1.961]
#  [2.878]
#  [1.381]
#  [2.529]
#  [1.753]
#  [0.935]
#  [2.196]
#  [2.592]
#  [3.434]
#  [3.79 ]
#  [3.359]
#  [4.008]
#  [2.398]
#  [2.788]
#  [4.292]
#  [2.378]
#  [1.189]
#  [2.435]
#  [3.684]
#  [3.814]
#  [1.69 ]
#  [1.468]
#  [1.519]
#  [3.384]
#  [3.392]
#  [2.256]
#  [3.791]
#  [2.162]
#  [2.618]
#  [1.836]
#  [2.034]
#  [1.611]
#  [2.107]
#  [3.199]
#  [0.65 ]
#  [2.948]
#  [1.759]
#  [2.172]
#  [2.025]
#  [2.567]
# ...

# %% [markdown]
# ## 2. TRAINING LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression ()
regressor.fit (X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## 3. PREDICTING TEST SET RESULTS

# %%
Y_pred = regressor.predict (X_test)
print (Y_pred)
# Out:
# [[2.03420208]
#  [3.18395878]
#  [3.20378217]
#  [3.22360556]
#  [2.43066991]
#  [3.04519504]
#  [2.98572487]
#  [3.18395878]
#  [1.81614477]
#  [2.4504933 ]
#  [2.70819739]
#  [2.94607808]
#  [3.42183948]
#  [3.32272252]
#  [2.15314243]
#  [3.16413539]
#  [2.19278921]
#  [2.60908043]
#  [2.29190617]
#  [1.71702782]
#  [3.40201609]
#  [3.28307574]
#  [1.7566746 ]
#  [2.52978686]
#  [2.92625469]
#  [2.58925704]
#  [1.69720442]
#  [3.34254591]
#  [2.47031669]
#  [2.58925704]
#  [2.09367225]
#  [1.7566746 ]
#  [2.82713773]
#  [2.09367225]
#  [2.9064313 ]
#  [1.67738103]
#  [1.9747319 ]
#  [1.67738103]
#  [2.78749095]
#  [1.57826408]
#  [2.82713773]
#  [2.96590147]
#  [2.05402547]
#  [2.60908043]
#  [2.37119973]
#  [3.50113304]
#  [2.25225938]
#  [2.78749095]
#  [2.09367225]
#  [2.84696113]
#  [2.37119973]
#  [2.23243599]
#  [2.76766756]
#  [2.05402547]
#  [2.33155295]
#  [1.69720442]
#  [2.35137634]
#  [2.70819739]
#  [3.42183948]
#  [2.23243599]
#  [3.40201609]
#  [3.46148626]
# ...

# %%
print (np.concatenate ((Y_pred.reshape (len (Y_pred),1), Y_test.reshape (len (Y_test),1)),1))
# Out:
# [[2.03420208 1.436     ]
#  [3.18395878 3.28      ]
#  [3.20378217 3.017     ]
#  [3.22360556 3.172     ]
#  [2.43066991 3.3       ]
#  [3.04519504 3.233     ]
#  [2.98572487 4.004     ]
#  [3.18395878 3.348     ]
#  [1.81614477 1.819     ]
#  [2.4504933  2.887     ]
#  [2.70819739 2.246     ]
#  [2.94607808 3.546     ]
#  [3.42183948 3.658     ]
#  [3.32272252 3.371     ]
#  [2.15314243 1.77      ]
#  [3.16413539 2.799     ]
#  [2.19278921 1.378     ]
#  [2.60908043 4.199     ]
#  [2.29190617 0.869     ]
#  [1.71702782 1.766     ]
#  [3.40201609 3.099     ]
#  [3.28307574 4.609     ]
#  [1.7566746  2.672     ]
#  [2.52978686 2.327     ]
#  [2.92625469 1.831     ]
#  [2.58925704 1.968     ]
#  [1.69720442 2.377     ]
#  [3.34254591 3.49      ]
#  [2.47031669 3.398     ]
#  [2.58925704 1.802     ]
#  [2.09367225 1.223     ]
#  [1.7566746  1.216     ]
#  [2.82713773 2.648     ]
#  [2.09367225 2.415     ]
#  [2.9064313  3.058     ]
#  [1.67738103 2.252     ]
#  [1.9747319  2.621     ]
# ...

# %% [markdown]
# ## 4. VISUALISING RESULTS

# %% [markdown]
# 4.1 TRAINING SET

# %%
plt.scatter (X_train, Y_train, color = 'red')
plt.plot (X_train, regressor.predict (X_train), color = 'blue')
plt.title ('TRAINING SET RESULTS')
plt.xlabel ('X')
plt.ylabel ('Y')
plt.show ()

# %% [markdown]
# 4.2 TEST SET

# %%
plt.scatter (X_test, Y_test, color = 'red')
plt.plot (X_test, Y_pred, color = 'blue')
plt.title ('TEST SET RESULTS')
plt.xlabel ('X')
plt.ylabel ('Y')
plt.show ()

# %% [markdown]
# ## 5. ACCURACY OF MODEL

# %%
from sklearn.metrics import r2_score
acc = r2_score (Y_test, Y_pred)
print ('Accuracy of Regression Model is - ', acc)
# Out:
# Accuracy of Regression Model is -  0.4435069542794855
